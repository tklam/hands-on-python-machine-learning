# %% [markdown]
# # Hands-on Introduction to Python And Machine Learning

# %% [markdown]
# Instructor: Tak-Kei Lam
#
# (Readers are assumed to have a little bit programming background.)

# %% [markdown]
# # Project 1
#
# ## Specification
# - Develop an expert system/artificial intelligence system that recommends which Pokemon should join a particular battle
# between two Pokemons.
# - The system shall get the opponent Pokemon name, and return a list of potential Pokemons which can likely beat the opponent.

# %% [markdown]
# We have the attributes for each Pokemon:

# %%
import pandas as pd

pokemons = pd.read_csv("pokemon.csv")
pokemons
# Out:
#        #                    Name    Type 1  Type 2   HP  Attack  Defense  \
# 0      1               Bulbasaur     Grass  Poison   45      49       49
# 1      2                 Ivysaur     Grass  Poison   60      62       63
# 2      3                Venusaur     Grass  Poison   80      82       83
# 3      4           Mega Venusaur     Grass  Poison   80     100      123
# 4      5              Charmander      Fire     NaN   39      52       43
# 5      6              Charmeleon      Fire     NaN   58      64       58
# 6      7               Charizard      Fire  Flying   78      84       78
# 7      8        Mega Charizard X      Fire  Dragon   78     130      111
# 8      9        Mega Charizard Y      Fire  Flying   78     104       78
# 9     10                Squirtle     Water     NaN   44      48       65
# 10    11               Wartortle     Water     NaN   59      63       80
# 11    12               Blastoise     Water     NaN   79      83      100
# ...

# %% [markdown]
# We also have some battle statistics. In the file [pokemon-combats.csv](pokemon-combats.csv), *First_pokemon*, *Second_pokemon* and *Winner* are the Pokemon IDs. The *First_pokemon* is also the Pokemon that attacked first.
#
# For example, in the first row, it was a battle between Larvitar (266) and Nuzleaf (298). Larvitar made the first attack.

# %%
import pandas as pd

pokemons = pd.read_csv("pokemon-combats.csv")
pokemons
# Out:
#        First_pokemon  Second_pokemon  Winner
# 0                266             298     298
# 1                702             701     701
# 2                191             668     668
# 3                237             683     683
# 4                151             231     151
# 5                657             752     657
# 6                192             134     134
# 7                 73             545     545
# 8                220             763     763
# 9                302              31      31
# 10               442             130     130
# 11               701             624     701
# 12                15             283     283
# 13               151              87     151
# 14               269             462     269
# 15               763             448     448
# 16               143             263     263
# 17               365             240     240
# 18               499             774     499
# 19               563             578     563
# ...

# %% [markdown]
# ## Suggested procedure
# 1. Merge the two sets of data
# 2. Clean the data (if necessary)
# 3. Select useful attributes from the data (if necessary)
# 4. Train a model using the most suitable method, or the most convenient method, or the the method that you are most familiar with
# 5. Test the model
# 6. Adjust the model parameters, or use another method if the model behaves not quite well
# 7. Repeat 2-6 (if necessary)

# %% [markdown]
# ## Deliverables
# 1. The Python files
# 2. A short report explaining your system design: how did you pre-process the data? what machine learning methods did you you? how accurate is the model? Graphs? And any other things that you want the readers to know. Please write your report as a Jupyter notebook.

# %% [markdown]
# # Project 2
#
# ## Specification
# - Improve the chatbot we have seen in [Contents](Contents - Hands-on Introduction to Python And Machine Learning.ipynb) to either:
#     1. Make it either faster (much more responsive) or more intelligent; OR
#     2. Make it be able to determine whether the user is happy or sad from the context of the conversation; OR
#     3. Make it more specific, e.g. a Pokemon expert that can answer most questions about Pokemon

# %% [markdown]
# ## Deliverables
# 1. The Python files
# 2. A short report explaining your system design: how did you pre-process the data? what machine learning methods did you you? how accurate is the model? Graphs? And any other things that you want the readers to know. Please write your report as a Jupyter notebook.
